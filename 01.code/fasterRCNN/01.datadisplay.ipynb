# %%
from detection.datasets import pascal_voc
from detection.datasets.utils import get_original_image
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/envs/dlcv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/envs/dlcv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/envs/dlcv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
# 获取数据
pascal = pascal_voc.pascal_voc("train")
image,image_meta,bboxes,label = pascal[8]

# %%
image.shape
# Out:
# (1, 1024, 1024, 3)

# %%
image_meta.shape
# Out:
# (1, 11)

# %%
bboxes.shape
# Out:
# (1, 4, 4)

# %%
label.shape
# Out:
# (1, 4)

# %%
# 图像均值和方差
mg_mean = (122.7717, 115.9465, 102.9801)
img_std = (1., 1., 1.)

# %%
# 原始图像
ori_image = get_original_image(image[0],image_meta[0],mg_mean).astype(np.uint8)
plt.imshow(ori_image)
plt.show()

# %%
# 送入网络中的图像
rgb_image = np.round(image[0]+mg_mean).astype(np.uint8)
plt.imshow(rgb_image)
plt.show()

# %%
import visualize

# %%
visualize.display_instances(rgb_image,bboxes[0],label[0],pascal.classes)
